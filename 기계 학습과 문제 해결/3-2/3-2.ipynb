# %%
import csv

f = open('iris.csv')
data = csv.reader(f)
result = []

for row in data:
	result.append(row)
	print(row)
# Out:
# ['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm', 'Species']
# ['1', '5.1', '3.5', '1.4', '0.2', 'Iris-setosa']
# ['2', '4.9', '3.0', '1.4', '0.2', 'Iris-setosa']
# ['3', '4.7', '3.2', '1.3', '0.2', 'Iris-setosa']
# ['4', '4.6', '3.1', '1.5', '0.2', 'Iris-setosa']
# ['5', '5.0', '3.6', '1.4', '0.2', 'Iris-setosa']
# ['6', '5.4', '3.9', '1.7', '0.4', 'Iris-setosa']
# ['7', '4.6', '3.4', '1.4', '0.3', 'Iris-setosa']
# ['8', '5.0', '3.4', '1.5', '0.2', 'Iris-setosa']
# ['9', '4.4', '2.9', '1.4', '0.2', 'Iris-setosa']
# ['10', '4.9', '3.1', '1.5', '0.1', 'Iris-setosa']
# ['11', '5.4', '3.7', '1.5', '0.2', 'Iris-setosa']
# ['12', '4.8', '3.4', '1.6', '0.2', 'Iris-setosa']
# ['13', '4.8', '3.0', '1.4', '0.1', 'Iris-setosa']
# ['14', '4.3', '3.0', '1.1', '0.1', 'Iris-setosa']
# ['15', '5.8', '4.0', '1.2', '0.2', 'Iris-setosa']
# ['16', '5.7', '4.4', '1.5', '0.4', 'Iris-setosa']
# ['17', '5.4', '3.9', '1.3', '0.4', 'Iris-setosa']
# ...

# %%
import csv

f = open('iris.csv')
data = csv.reader(f)
header = next(data)
result = []

# 전체 데이터를 행별로 result 리스트에 저장하기
for row in data:
	result.append(row)

# result에 저장된 값 중 꽃받침과 꽃잎의 길이, 너비 값을 숫자로 바꾼 후 출력하기
for i in result:
	for j in range(1, 5):
		i[j] = float(i[j])
	print(i)
# Out:
# ['1', 5.1, 3.5, 1.4, 0.2, 'Iris-setosa']
# ['2', 4.9, 3.0, 1.4, 0.2, 'Iris-setosa']
# ['3', 4.7, 3.2, 1.3, 0.2, 'Iris-setosa']
# ['4', 4.6, 3.1, 1.5, 0.2, 'Iris-setosa']
# ['5', 5.0, 3.6, 1.4, 0.2, 'Iris-setosa']
# ['6', 5.4, 3.9, 1.7, 0.4, 'Iris-setosa']
# ['7', 4.6, 3.4, 1.4, 0.3, 'Iris-setosa']
# ['8', 5.0, 3.4, 1.5, 0.2, 'Iris-setosa']
# ['9', 4.4, 2.9, 1.4, 0.2, 'Iris-setosa']
# ['10', 4.9, 3.1, 1.5, 0.1, 'Iris-setosa']
# ['11', 5.4, 3.7, 1.5, 0.2, 'Iris-setosa']
# ['12', 4.8, 3.4, 1.6, 0.2, 'Iris-setosa']
# ['13', 4.8, 3.0, 1.4, 0.1, 'Iris-setosa']
# ['14', 4.3, 3.0, 1.1, 0.1, 'Iris-setosa']
# ['15', 5.8, 4.0, 1.2, 0.2, 'Iris-setosa']
# ['16', 5.7, 4.4, 1.5, 0.4, 'Iris-setosa']
# ['17', 5.4, 3.9, 1.3, 0.4, 'Iris-setosa']
# ['18', 5.1, 3.5, 1.4, 0.3, 'Iris-setosa']
# ['19', 5.7, 3.8, 1.7, 0.3, 'Iris-setosa']
# ['20', 5.1, 3.8, 1.5, 0.3, 'Iris-setosa']
# ['21', 5.4, 3.4, 1.7, 0.2, 'Iris-setosa']
# ['22', 5.1, 3.7, 1.5, 0.4, 'Iris-setosa']
# ...

# %%
import csv

f = open('iris.csv')
data = csv.reader(f)
header = next(data)
result = []

for row in data:
    result.append(row)
    for i in range(1, 5):
            row[i] = float(row[i])

print(result)
# Out:
# [['1', 5.1, 3.5, 1.4, 0.2, 'Iris-setosa'], ['2', 4.9, 3.0, 1.4, 0.2, 'Iris-setosa'], ['3', 4.7, 3.2, 1.3, 0.2, 'Iris-setosa'], ['4', 4.6, 3.1, 1.5, 0.2, 'Iris-setosa'], ['5', 5.0, 3.6, 1.4, 0.2, 'Iris-setosa'], ['6', 5.4, 3.9, 1.7, 0.4, 'Iris-setosa'], ['7', 4.6, 3.4, 1.4, 0.3, 'Iris-setosa'], ['8', 5.0, 3.4, 1.5, 0.2, 'Iris-setosa'], ['9', 4.4, 2.9, 1.4, 0.2, 'Iris-setosa'], ['10', 4.9, 3.1, 1.5, 0.1, 'Iris-setosa'], ['11', 5.4, 3.7, 1.5, 0.2, 'Iris-setosa'], ['12', 4.8, 3.4, 1.6, 0.2, 'Iris-setosa'], ['13', 4.8, 3.0, 1.4, 0.1, 'Iris-setosa'], ['14', 4.3, 3.0, 1.1, 0.1, 'Iris-setosa'], ['15', 5.8, 4.0, 1.2, 0.2, 'Iris-setosa'], ['16', 5.7, 4.4, 1.5, 0.4, 'Iris-setosa'], ['17', 5.4, 3.9, 1.3, 0.4, 'Iris-setosa'], ['18', 5.1, 3.5, 1.4, 0.3, 'Iris-setosa'], ['19', 5.7, 3.8, 1.7, 0.3, 'Iris-setosa'], ['20', 5.1, 3.8, 1.5, 0.3, 'Iris-setosa'], ['21', 5.4, 3.4, 1.7, 0.2, 'Iris-setosa'], ['22', 5.1, 3.7, 1.5, 0.4, 'Iris-setosa'], ['23', 4.6, 3.6, 1.0, 0.2, 'Iris-setosa'], ['24', 5.1, 3.3, 
# ...

# %%
import csv

f = open('iris.csv')
data = csv.reader(f)
header = next(data)
result = []

# 전체 데이터를 행별로 result 리스트에 저장하기
for row in data:
	result.append(row)

# result에 저장된 값 중 꽃받침과 꽃잎의 길이, 너비 값을 숫자로 바꾼 후 출력하기
for i in result:
	for j in range(1, 5):
		i[j] = float(i[j])

# 꽃 종류별 데이터 확인하기
a = []
b = []
c = []

for i in result:
	if i[5] == 'Iris-setosa':
		a.append(i[0:5])
	if i[5] == 'Iris-versicolor':
		b.append(i[0:5])
	if i[5] == 'Iris-virginica':
		c.append(i[0:5])

# %%
# Iris-setosa의 꽃잎과 꽃받침의 길이, 너비에 따른 평균 구하기
SL = []
SW = []
PL = []
PW = []

for i in a:
	SL.append(i[1])
	SW.append(i[2])
	PL.append(i[3])
	PW.append(i[4])

print('<iris-setosa의 특성별 평균>')
print('꽃받침 길이 평균:', round(sum(SL)/len(SL),3), '\n꽃받침 너비 평균:', round(sum(SW)/len(SW),3), '\n꽃잎 길이 평균:', round(sum(PL)/len(PL),3), '\n꽃잎 너비 평균:', round(sum(PW)/len(PW),3))
# Out:
# <iris-setosa의 특성별 평균>
# 꽃받침 길이 평균: 5.006
# 꽃받침 너비 평균: 3.418
# 꽃잎 길이 평균: 1.464
# 꽃잎 너비 평균: 0.244

# %%
# Iris-setosa의 꽃잎과 꽃받침의 길이, 너비에 따른 평균 구하기
SL.sort()
SW.sort()
PL.sort()
PW.sort()
m = int(len(a)/2)

print('<Iris-setosa의 특성별 중앙값>')
print('꽃받침 길이 중악밧:', SL[m], '\n꽃받침 너비 중앙값:', SW[m], '\n꽃잎 길이 중앙값:', PL[m], '\n꽃잎 너비 중앙값:', PW[m])
# Out:
# <Iris-setosa의 특성별 중앙값>
# 꽃받침 길이 중악밧: 5.0
# 꽃받침 너비 중앙값: 3.4
# 꽃잎 길이 중앙값: 1.5
# 꽃잎 너비 중앙값: 0.2

# %%
import pandas as pd

iris = pd.read_csv('Iris.csv')

print(iris.head(2))
print(iris.info())
print(iris.describe())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
# None
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# ...

# %%
import matplotlib.pyplot as plt
# 꽃받침(Sepal)의 길이와 너비에 따른 분산형(scatter) 그래프
fig = iris[iris.Species == 'Iris-setosa'].plot(kind='scatter',x='SepalLengthCm',y='SepalWidthCm',color='orange',label='setosa')
iris[iris.Species == 'Iris-versicolor'].plot(kind='scatter',x='SepalLengthCm',y='SepalWidthCm',color='blue',label='vesicolor',ax=fig)
iris[iris.Species == 'Iris-virginica'].plot(kind='scatter',x='SepalLengthCm',y='SepalWidthCm',color='green',label='virginica',ax=fig)
fig.set_xlabel('Sepal Length')
fig.set_ylabel('Sepal Width')
fig.set_title('Sepal Length VS Width')
fig = plt.gcf()
fig.set_size_inches(10, 6)
plt.show()

# %%
# 꽃받침(Sepal)의 길이와 너비에 따른 분산형(scatter) 그래프
fig = iris[iris.Species == 'Iris-setosa'].plot(kind='scatter',x='PetalLengthCm',y='PetalWidthCm',color='orange',label='setosa')
iris[iris.Species == 'Iris-versicolor'].plot(kind='scatter',x='PetalLengthCm',y='PetalWidthCm',color='blue',label='vesicolor',ax=fig)
iris[iris.Species == 'Iris-virginica'].plot(kind='scatter',x='PetalLengthCm',y='PetalWidthCm',color='green',label='virginica',ax=fig)
fig.set_xlabel('Petal Length')
fig.set_ylabel('Petal Width')
fig.set_title('Petal Length VS Width')
fig = plt.gcf()
fig.set_size_inches(10, 6)
plt.show()

# %%
import pandas as pd

iris = pd.read_csv('Iris.csv')

# %%
import numpy as np # 모듈 호출

# 계산의 편의를 위해 데이터 셋의 형식을 numpy로 변환
xy = np.array(iris)
# 테이블의 1~4 열벡터를 features에 저장
features = xy[:, 1:-1]
# 테이블의 마지막 열벡터를 target_value에 저장
target_value = xy[:, [-1]]

# %%
import csv

f = open('iris.csv')
data = csv.reader(f)
result = []

for row in data:
	result.append(row)
	print(row)
# Out:
# ['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm', 'Species']
# ['1', '5.1', '3.5', '1.4', '0.2', 'Iris-setosa']
# ['2', '4.9', '3.0', '1.4', '0.2', 'Iris-setosa']
# ['3', '4.7', '3.2', '1.3', '0.2', 'Iris-setosa']
# ['4', '4.6', '3.1', '1.5', '0.2', 'Iris-setosa']
# ['5', '5.0', '3.6', '1.4', '0.2', 'Iris-setosa']
# ['6', '5.4', '3.9', '1.7', '0.4', 'Iris-setosa']
# ['7', '4.6', '3.4', '1.4', '0.3', 'Iris-setosa']
# ['8', '5.0', '3.4', '1.5', '0.2', 'Iris-setosa']
# ['9', '4.4', '2.9', '1.4', '0.2', 'Iris-setosa']
# ['10', '4.9', '3.1', '1.5', '0.1', 'Iris-setosa']
# ['11', '5.4', '3.7', '1.5', '0.2', 'Iris-setosa']
# ['12', '4.8', '3.4', '1.6', '0.2', 'Iris-setosa']
# ['13', '4.8', '3.0', '1.4', '0.1', 'Iris-setosa']
# ['14', '4.3', '3.0', '1.1', '0.1', 'Iris-setosa']
# ['15', '5.8', '4.0', '1.2', '0.2', 'Iris-setosa']
# ['16', '5.7', '4.4', '1.5', '0.4', 'Iris-setosa']
# ['17', '5.4', '3.9', '1.3', '0.4', 'Iris-setosa']
# ...

# %%
import csv

f = open('iris.csv')
data = csv.reader(f)
header = next(data)
result = []

# 전체 데이터를 행별로 result 리스트에 저장하기
for row in data:
	result.append(row)

# result에 저장된 값 중 꽃받침과 꽃잎의 길이, 너비 값을 숫자로 바꾼 후 출력하기
for i in result:
	for j in range(1, 5):
		i[j] = float(i[j])
	print(i)
# Out:
# ['1', 5.1, 3.5, 1.4, 0.2, 'Iris-setosa']
# ['2', 4.9, 3.0, 1.4, 0.2, 'Iris-setosa']
# ['3', 4.7, 3.2, 1.3, 0.2, 'Iris-setosa']
# ['4', 4.6, 3.1, 1.5, 0.2, 'Iris-setosa']
# ['5', 5.0, 3.6, 1.4, 0.2, 'Iris-setosa']
# ['6', 5.4, 3.9, 1.7, 0.4, 'Iris-setosa']
# ['7', 4.6, 3.4, 1.4, 0.3, 'Iris-setosa']
# ['8', 5.0, 3.4, 1.5, 0.2, 'Iris-setosa']
# ['9', 4.4, 2.9, 1.4, 0.2, 'Iris-setosa']
# ['10', 4.9, 3.1, 1.5, 0.1, 'Iris-setosa']
# ['11', 5.4, 3.7, 1.5, 0.2, 'Iris-setosa']
# ['12', 4.8, 3.4, 1.6, 0.2, 'Iris-setosa']
# ['13', 4.8, 3.0, 1.4, 0.1, 'Iris-setosa']
# ['14', 4.3, 3.0, 1.1, 0.1, 'Iris-setosa']
# ['15', 5.8, 4.0, 1.2, 0.2, 'Iris-setosa']
# ['16', 5.7, 4.4, 1.5, 0.4, 'Iris-setosa']
# ['17', 5.4, 3.9, 1.3, 0.4, 'Iris-setosa']
# ['18', 5.1, 3.5, 1.4, 0.3, 'Iris-setosa']
# ['19', 5.7, 3.8, 1.7, 0.3, 'Iris-setosa']
# ['20', 5.1, 3.8, 1.5, 0.3, 'Iris-setosa']
# ['21', 5.4, 3.4, 1.7, 0.2, 'Iris-setosa']
# ['22', 5.1, 3.7, 1.5, 0.4, 'Iris-setosa']
# ...

# %%
import csv

f = open('iris.csv')
data = csv.reader(f)
header = next(data)
result = []

for row in data:
    result.append(row)
    for i in range(1, 5):
            row[i] = float(row[i])

print(result)
# Out:
# [['1', 5.1, 3.5, 1.4, 0.2, 'Iris-setosa'], ['2', 4.9, 3.0, 1.4, 0.2, 'Iris-setosa'], ['3', 4.7, 3.2, 1.3, 0.2, 'Iris-setosa'], ['4', 4.6, 3.1, 1.5, 0.2, 'Iris-setosa'], ['5', 5.0, 3.6, 1.4, 0.2, 'Iris-setosa'], ['6', 5.4, 3.9, 1.7, 0.4, 'Iris-setosa'], ['7', 4.6, 3.4, 1.4, 0.3, 'Iris-setosa'], ['8', 5.0, 3.4, 1.5, 0.2, 'Iris-setosa'], ['9', 4.4, 2.9, 1.4, 0.2, 'Iris-setosa'], ['10', 4.9, 3.1, 1.5, 0.1, 'Iris-setosa'], ['11', 5.4, 3.7, 1.5, 0.2, 'Iris-setosa'], ['12', 4.8, 3.4, 1.6, 0.2, 'Iris-setosa'], ['13', 4.8, 3.0, 1.4, 0.1, 'Iris-setosa'], ['14', 4.3, 3.0, 1.1, 0.1, 'Iris-setosa'], ['15', 5.8, 4.0, 1.2, 0.2, 'Iris-setosa'], ['16', 5.7, 4.4, 1.5, 0.4, 'Iris-setosa'], ['17', 5.4, 3.9, 1.3, 0.4, 'Iris-setosa'], ['18', 5.1, 3.5, 1.4, 0.3, 'Iris-setosa'], ['19', 5.7, 3.8, 1.7, 0.3, 'Iris-setosa'], ['20', 5.1, 3.8, 1.5, 0.3, 'Iris-setosa'], ['21', 5.4, 3.4, 1.7, 0.2, 'Iris-setosa'], ['22', 5.1, 3.7, 1.5, 0.4, 'Iris-setosa'], ['23', 4.6, 3.6, 1.0, 0.2, 'Iris-setosa'], ['24', 5.1, 3.3, 
# ...

# %%
import csv

f = open('iris.csv')
data = csv.reader(f)
header = next(data)
result = []

# 전체 데이터를 행별로 result 리스트에 저장하기
for row in data:
	result.append(row)

# result에 저장된 값 중 꽃받침과 꽃잎의 길이, 너비 값을 숫자로 바꾼 후 출력하기
for i in result:
	for j in range(1, 5):
		i[j] = float(i[j])

# 꽃 종류별 데이터 확인하기
a = []
b = []
c = []

for i in result:
	if i[5] == 'Iris-setosa':
		a.append(i[0:5])
	if i[5] == 'Iris-versicolor':
		b.append(i[0:5])
	if i[5] == 'Iris-virginica':
		c.append(i[0:5])

# %%
# Distance 함수 만들기
def Distance(A, B):
	return np.sqrt(np.sum(np.power((A-B), 2)))

# %%
import numpy as np # numpy 라이브러리 추가

# 두 점 A(1,2)와 B(5,7) 선언
A = np.array([1, 2])
B = np.array([5, 7])
# 두 점 A(1,2)와 B(5,7) 사이의 거리를 계산하는 변수 distance에 저장하기
distance = np.sqrt(np.sum(np.power((A-B), 2)))
# 변수 distance에 저장된 값을 소수점 셋째 자리에서 반올림하기
distance = round(distance, 2)
# 계산 결과 출력하기
print('두 점 A(1,2)와 B(5,7) 사이의 거리는 {0} 입니다.'.format(distance))
# Out:
# 두 점 A(1,2)와 B(5,7) 사이의 거리는 6.4 입니다.

# %%
def K_NN(Unknown, features, K):
    distance_result = np.zeros(150)
	
    for i in range(150):
        distance_result[i] = Distance(Unknown, features[i])

    index = distance_result.argsort()

    target_result = []
    result = [0, 0, 0]
    for i in range(K):
        target_result.append(target_value[index[i]])
        if target_result[i] == 'Iris-setosa':
            result[0] += 1
        elif target_result[i] == 'Iris-versicolor':
            result[1] += 1
        else:
            result[2] += 1

    # ④ 붓꽃 분류 함수 - 레이블의 빈도가 가장 높은 값 반환
    max_label = result.index(max(result))
    species = {0: 'setosa', 1: 'versicolor', 2: 'virginica'}
    species_result = species[max_label]
	
    return species_result

# %%
# argsort() 함수 알아보기
# 기능: 작은 값부터 순서대로 데이터의 인덱스(index)를 반환함.
sample = np.array([10, 2, 1, 5])
result = sample.argsort()
print(result)
print('가장 작은 값은 {0}이며, 인덱스 번호는 {1}입니다.'.format(sample[result[0]], result[0]))
# Out:
# [2 1 3 0]
# 가장 작은 값은 1이며, 인덱스 번호는 2입니다.

# %%
# 마지막 150번째 데이터(인덱스 번호는 0부터이므로 149)
test_1 = features[149]
# 150번째와 유사한 가상의 데이터
test_2 = np.array([6, 2.9, 5, 2])

# K_NN 분류 함수를 이용하여 분류하기
result_1 = K_NN(test_1, features, 3)
result_2 = K_NN(test_2, features, 3)

# 결과 출력하기
print('실제 데이터를 분류한 결과: {0}'.format(result_1))
print('가상 데이터를 분류한 결과: {0}'.format(result_2))
# Out:
# 실제 데이터를 분류한 결과: virginica
# 가상 데이터를 분류한 결과: virginica

# %%
# 그림에서 수집한 데이터
ID_1 = np.array([2.7, 2.4, 1.65, 0.67])
ID_2 = np.array([5.84, 5.48, 3, 2.16])
ID_3 = np.array([3.97, 4.01, 1.7, 0.67])

# K_NN 분류 함수를 이용하여 분류하기
result_1 = K_NN(ID_1, features, 5)
result_2 = K_NN(ID_2, features, 5)
result_3 = K_NN(ID_3, features, 5)

# 분류 결과 출력하기
print(result_1, result_2, result_3)
# Out:
# setosa setosa setosa
